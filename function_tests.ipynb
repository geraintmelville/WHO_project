# %%
from functions import load_data, train_test_split_spec, encode_regions, fit_model, train_all_models, scale_data, view_model
# Out:
# 2026-07-22 17:27:13.613 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import RobustScaler

# %%
SENSITIVE_COLS = [
    "Adult_mortality",
    "Infant_deaths",
    "Under_five_deaths",
    "Incidents_HIV",
    "Hepatitis_B",
    "Measles",
    "Polio",
    "Diphtheria",
    "BMI",
    "Thinness_ten_nineteen_years",
    "Thinness_five_nine_years",
    "Alcohol_consumption"]

# %%
df = load_data()
# Out:
# 2026-07-22 17:27:17.519 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-07-22 17:27:17.527 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df_train, df_test = train_test_split_spec(df,test_size = 0.2,random_state = 41)

# %%
df_train_enc, df_test_enc = encode_regions(df_train, df_test)

# %%
df_train_scaled, df_test_scaled, scaler = scale_data(df_train_enc, df_test_enc)

# %%
bundle_rob = fit_model(df_train_scaled, df_test_scaled, drop_cols = [])

# %%
view_model(bundle_rob)
# Out:
#   Year: 0.22
#   Infant_deaths: -2.15
#   Under_five_deaths: -3.00
#   Adult_mortality: -6.73
#   Alcohol_consumption: 0.19
#   Hepatitis_B: -0.19
#   Measles: 0.01
#   BMI: -0.62
#   Polio: 0.28
#   Diphtheria: -0.17
#   Incidents_HIV: 0.04
#   GDP_per_capita: 0.28
#   Population_mln: -0.01
#   Thinness_ten_nineteen_years: -0.19
#   Thinness_five_nine_years: 0.22
#   Schooling: 0.72
#   Economy_status_Developed: 0.92
#   Economy_status_Developing: -0.92
#   Region_Asia: 0.33
#   Region_Central America and Caribbean: 2.29
#   Region_European Union: -0.17
#   Region_Middle East: 0.69
#   Region_North America: 1.24
#   Region_Oceania: -0.83
#   Region_Rest of Europe: 0.21
#   Region_South America: 1.86
# Train RMSE: 1.1737456568432867
# Test RMSE: 1.3655352109811454

# %%
bundle_eth = fit_model(df_train_scaled, df_test_scaled, drop_cols = SENSITIVE_COLS)

# %%
view_model(bundle_eth)
# Out:
#   Year: 1.91
#   GDP_per_capita: 1.58
#   Population_mln: 0.03
#   Schooling: 3.45
#   Economy_status_Developed: 0.18
#   Economy_status_Developing: -0.18
#   Region_Asia: 9.21
#   Region_Central America and Caribbean: 12.47
#   Region_European Union: 12.10
#   Region_Middle East: 11.89
#   Region_North America: 10.09
#   Region_Oceania: 7.51
#   Region_Rest of Europe: 9.82
#   Region_South America: 12.24
# Train RMSE: 4.526882702639366
# Test RMSE: 5.79396896996334
